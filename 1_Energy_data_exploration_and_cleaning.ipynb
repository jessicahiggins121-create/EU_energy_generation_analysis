# %% [markdown]
# Here we will explore the data, get to know the data types, and if there are any inconsistencies, based from the data documentation given.

# %%
import pandas as pd

# %%
url = "Your_Google_drive_link" ## add your own google drive infor
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
MES_data = pd.read_csv(path)
# Out:
# /tmp/ipython-input-1217886434.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   MES_data = pd.read_csv(path)

# %%
MES_data_1 = MES_data.copy()
MES_data_1 = pd.DataFrame(MES_data)

# %%
MES_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154930 entries, 0 to 154929
# Data columns (total 6 columns):
#  #   Column                                                                                                                                                 Non-Null Count   Dtype
# ---  ------                                                                                                                                                 --------------   -----
#  0   The Monthly electricity data explorer and the main highlights are available here: https://www.iea.org/reports/monthly-electricity-statistics-overview  154928 non-null  object
#  1   Unnamed: 1                                                                                                                                             154924 non-null  object
# ...

# %%
# drop information not needed for analysis and renamed columns

MES_data_1.head(10)

MES_data_1 = MES_data_1.drop([0,1,2,3,4,5,6,7,8],axis = 0).copy()

MES_data_1 = MES_data_1.rename( columns = {'The Monthly electricity data explorer and the main highlights are available here: https://www.iea.org/reports/monthly-electricity-statistics-overview':'country',
                              'Unnamed: 1':'date','Unnamed: 2':'balance', 'Unnamed: 3':'product', 'Unnamed: 4':'value', 'Unnamed: 5':'unit'}).copy()

# %%
# check column types, for duplicates, null, values,
MES_data_1.info() # need to transform data to year and month, and value to int64.

MES_data_1.duplicated() # zero duplicate enteries
MES_data_1.describe()

MES_data_1.isna().sum() # 51 null values -
MES_data_1['value'].isna().value_counts(normalize=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154921 entries, 9 to 154929
# Data columns (total 6 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   country  154921 non-null  object
#  1   date     154921 non-null  object
#  2   balance  154921 non-null  object
#  3   product  154921 non-null  object
#  4   value    154870 non-null  object
#  5   unit     154921 non-null  object
# dtypes: object(6)
# memory usage: 7.1+ MB
# value
# False    0.999671
# True     0.000329
# Name: proportion, dtype: float64

# %%
# drop na values
MES_data_1 = MES_data_1.dropna(axis=0).copy()
MES_data_1.isna().sum()
# Out:
# country    0
# date       0
# balance    0
# product    0
# value      0
# unit       0
# dtype: int64

# %%
MES_data_1.head(50)
# Out:
#       country         date                         balance  \
# 9   Australia  August 2025      Net Electricity Production
# 10  Australia  August 2025      Net Electricity Production
# 11  Australia  August 2025      Net Electricity Production
# 12  Australia  August 2025      Net Electricity Production
# 13  Australia  August 2025      Net Electricity Production
# 14  Australia  August 2025      Net Electricity Production
# 15  Australia  August 2025      Net Electricity Production
# 16  Australia  August 2025      Net Electricity Production
# 17  Australia  August 2025         Used for pumped storage
# 18  Australia  August 2025             Distribution Losses
# 19  Australia  August 2025  Final Consumption (Calculated)
# 20  Australia  August 2025      Net Electricity Production
# 21    Austria  August 2025      Net Electricity Production
# 22    Austria  August 2025      Net Electricity Production
# 23    Austria  August 2025      Net Electricity Production
# ...

# %% [markdown]
# Need to think about if we want to get the data only for one country and if we shold split this up into different tables to pull information from.
#
# Also want to konw all the other catagories for product.

# %%
# Need to change date to an actual data and value to int64
MES_data_1['date']= pd.to_datetime(MES_data_1['date'].astype(str), format='%B %Y')
MES_data_1['date']
# Out:
# 9        2025-08-01
# 10       2025-08-01
# 11       2025-08-01
# 12       2025-08-01
# 13       2025-08-01
#             ...
# 154925   2010-01-01
# 154926   2010-01-01
# 154927   2010-01-01
# 154928   2010-01-01
# 154929   2010-01-01
# Name: date, Length: 154870, dtype: datetime64[ns]

# %%
MES_data_1['value'] = pd.to_numeric(MES_data_1['value'], downcast='float')
MES_data_1['value']
# Out:
# 9           1091.6230
# 10         15191.0630
# 11         10411.6566
# 12           409.1507
# 13          4110.1169
#              ...
# 154925     32372.5830
# 154926      6869.2530
# 154927     62000.7330
# 154928    877213.6150
# 154929     21659.6120
# Name: value, Length: 154870, dtype: float64

# %%
MES_data_1.to_csv("MES_data_1_clean.csv", index=False)
